# %%
import pandas as pd

df_data_1 = pd.read_csv('Loan_Training_data.csv')
pd.options.display.max_columns = 100

df_data_1.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
df_loan = df_data_1

# %%
#remove all the invalid inputs like NA and NaN
df_loan.dropna()
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 1    LP001003       0        1          1          1              0
# 2    LP001005       0        1          0          1              1
# 3    LP001006       0        1          0          0              0
# 4    LP001008       0        0          0          1              0
# 5    LP001011       0        1          2          1              1
# 6    LP001013       0        1          0          0              0
# 7    LP001014       0        1          3          1              0
# 8    LP001018       0        1          2          1              0
# 9    LP001020       0        1          1          1              0
# 10   LP001024       0        1          2          1              0
# 12   LP001028       0        1          2          1              0
# 13   LP001029       0        0          0          1              0
# 14   LP001030       0        1          2          1              0
# 15   LP001032       0        0          0          1              0
# 17   LP001036       1        0          0          1              0
# 18   LP001038       0        1          0          0              0
# 20   LP001043       0        1          0          0              0
# 21   LP001046       0        1          1          1              0
# 22   LP001047       0        1          0          0              0
# 25   LP001066       0        1          0          1              1
# 26   LP001068       0        1          0          1              0
# 27   LP001073       0        1          2          0              0
# 28   LP001086       0        0          0          0              0
# 31   LP001095       0        0          0          1              0
# 32   LP001097       0        0          1          1              1
# 33   LP001098       0        1          0          1              0
# 34   LP001100       0        0          3          1              0
# 37   LP001112       1        1          0          1              0
# 38   LP001114       0        0          0          1              0
# 39   LP001116       0        0          0          0              0
# ..        ...     ...      ...        ...        ...            ...
# 575  LP002868       0        1          2          1              0
# 577  LP002874       0        0          0          1              0
# 578  LP002877       0        1          1          1              0
# 580  LP002892       0        1          2          1              0
# 581  LP002893       0        0          0          1              0
# 582  LP002894       1        1          0          1              0
# 584  LP002911       0        1          1          1              0
# 585  LP002912       0        1          1          1              0
# 586  LP002916       0        1          0          1              0
# 587  LP002917       1        0          0          0              0
# 589  LP002926       0        1          2          1              1
# 590  LP002928       0        1          0          1              0
# 591  LP002931       0        1          2          1              1
# 593  LP002936       0        1          0          1              0
# 594  LP002938       0        1          0          1              1
# 595  LP002940       0        0          0          0              0
# 596  LP002941       0        1          2          0              1
# 598  LP002945       0        1          0          1              1
# 599  LP002948       0        1          2          1              0
# 602  LP002953       0        1          3          1              0
# 603  LP002958       0        0          0          1              0
# 604  LP002959       1        1          1          1              0
# 606  LP002961       0        1          1          1              0
# 607  LP002964       0        1          2          0              0
# 608  LP002974       0        1          0          1              0
# 609  LP002978       1        0          0          1              0
# 610  LP002979       0        1          3          1              0
# 611  LP002983       0        1          1          1              0
# 612  LP002984       0        1          2          1              0
# 613  LP002990       1        0          0          1              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# 5               5417             4196.0       267.0             360.0
# 6               2333             1516.0        95.0             360.0
# 7               3036             2504.0       158.0             360.0
# 8               4006             1526.0       168.0             360.0
# 9              12841            10968.0       349.0             360.0
# 10              3200              700.0        70.0             360.0
# 12              3073             8106.0       200.0             360.0
# 13              1853             2840.0       114.0             360.0
# 14              1299             1086.0        17.0             120.0
# 15              4950                0.0       125.0             360.0
# 17              3510                0.0        76.0             360.0
# 18              4887                0.0       133.0             360.0
# 20              7660                0.0       104.0             360.0
# 21              5955             5625.0       315.0             360.0
# 22              2600             1911.0       116.0             360.0
# 25              9560                0.0       191.0             360.0
# 26              2799             2253.0       122.0             360.0
# 27              4226             1040.0       110.0             360.0
# 28              1442                0.0        35.0             360.0
# 31              3167                0.0        74.0             360.0
# 32              4692                0.0       106.0             360.0
# 33              3500             1667.0       114.0             360.0
# 34             12500             3000.0       320.0             360.0
# 37              3667             1459.0       144.0             360.0
# 38              4166             7210.0       184.0             360.0
# 39              3748             1668.0       110.0             360.0
# ..               ...                ...         ...               ...
# 575             3159              461.0       108.0              84.0
# 577             3229             2739.0       110.0             360.0
# 578             1782             2232.0       107.0             360.0
# 580             6540                0.0       205.0             360.0
# 581             1836            33837.0        90.0             360.0
# 582             3166                0.0        36.0             360.0
# 584             2787             1917.0       146.0             360.0
# 585             4283             3000.0       172.0              84.0
# 586             2297             1522.0       104.0             360.0
# 587             2165                0.0        70.0             360.0
# 589             2726                0.0       106.0             360.0
# 590             3000             3416.0        56.0             180.0
# 591             6000                0.0       205.0             240.0
# 593             3859             3300.0       142.0             180.0
# 594            16120                0.0       260.0             360.0
# 595             3833                0.0       110.0             360.0
# 596             6383             1000.0       187.0             360.0
# 598             9963                0.0       180.0             360.0
# 599             5780                0.0       192.0             360.0
# 602             5703                0.0       128.0             360.0
# 603             3676             4301.0       172.0             360.0
# 604            12000                0.0       496.0             360.0
# 606             3400             2500.0       173.0             360.0
# 607             3987             1411.0       157.0             360.0
# 608             3232             1950.0       108.0             360.0
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History  Property_Area Loan_Status
# 1               1.0              0           N
# 2               1.0              1           Y
# 3               1.0              1           Y
# 4               1.0              1           Y
# 5               1.0              1           Y
# 6               1.0              1           Y
# 7               0.0              2           N
# 8               1.0              1           Y
# 9               1.0              2           N
# 10              1.0              1           Y
# 12              1.0              1           Y
# 13              1.0              0           N
# 14              1.0              1           Y
# 15              1.0              1           Y
# 17              0.0              1           N
# 18              1.0              0           N
# 20              0.0              1           N
# 21              1.0              1           Y
# 22              0.0              2           N
# 25              1.0              2           Y
# 26              1.0              2           Y
# 27              1.0              1           Y
# 28              1.0              1           N
# 31              1.0              1           N
# 32              1.0              0           N
# 33              1.0              2           Y
# 34              1.0              0           N
# 37              1.0              2           Y
# 38              1.0              1           Y
# 39              1.0              2           Y
# ..              ...            ...         ...
# 575             1.0              1           Y
# 577             1.0              1           Y
# 578             1.0              0           Y
# 580             1.0              2           Y
# 581             1.0              1           N
# 582             1.0              2           Y
# 584             0.0              0           N
# 585             1.0              0           N
# 586             1.0              1           Y
# 587             1.0              2           Y
# 589             0.0              2           N
# 590             1.0              2           Y
# 591             1.0              2           N
# 593             1.0              0           Y
# 594             1.0              1           Y
# 595             1.0              0           Y
# 596             1.0              0           N
# 598             1.0              0           Y
# 599             1.0              1           Y
# 602             1.0              1           Y
# 603             1.0              0           Y
# 604             1.0              2           Y
# 606             1.0              2           Y
# 607             1.0              0           Y
# 608             1.0              0           Y
# 609             1.0              0           Y
# 610             1.0              0           Y
# 611             1.0              1           Y
# 612             1.0              1           Y
# 613             0.0              2           N
#
# [480 rows x 13 columns]

# %%
#Convert the string columns into integer columns by converting the words into numbers
#df_loan['Gender'].replace(to_replace = ['Male', 'Female'], value = [0,1], inplace = True)
#df_loan['Property_Area'].replace(to_replace = ['Rural', 'Urban', 'Semiurban'], value = [0,1,2], inplace = True)
#df_loan['Dependents'].replace(to_replace = ['3+'], value = [3], inplace = True)
#df_loan['Married'].replace(to_replace = ['No', 'Yes'], value = [0,1], inplace = True)
#df_loan['Education'].replace(to_replace = ['Not Graduate', 'Graduate'], value = [0,1], inplace = True)
#df_loan['Self_Employed'].replace(to_replace = ['No', 'Yes'], value = [0,1], inplace = True)
df_loan.head()
# Out:
#     Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 1  LP001003       0        1          1          1              0
# 2  LP001005       0        1          0          1              1
# 3  LP001006       0        1          0          0              0
# 4  LP001008       0        0          0          1              0
# 5  LP001011       0        1          2          1              1
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
#
#    Credit_History  Property_Area Loan_Status
# 1             1.0              0           N
# 2             1.0              1           Y
# 3             1.0              1           Y
# 4             1.0              1           Y
# 5             1.0              1           Y

# %%
df_loan['Gender'].value_counts()
# Out:
# 0    394
# 1     86
# Name: Gender, dtype: int64

# %%
df_loan['Education'].value_counts()
# Out:
# 1    383
# 0     97
# Name: Education, dtype: int64

# %%
#Data Exploration
import matplotlib.pyplot as plt
import pylab as pl
import numpy as np
import pandas as pd

# %%
df_loan1 = df_loan[['Education', 'Gender']]

# %%
df_loan1 = pd.concat([df_loan1, pd.get_dummies(df_loan['Loan_Status'])], axis = 1)
df_loan1.head()
# Out:
#    Education  Gender  N  Y
# 1          1       0  1  0
# 2          1       0  0  1
# 3          0       0  0  1
# 4          1       0  0  1
# 5          1       0  0  1

# %%
#df_loan1['Demographic'] = df_loan1['Gender'].str.cat(df_loan1['Education'], sep = ",")

# %%
df_loan2 = df_loan1['Education'].value_counts().to_frame()
df_loan2.rename(columns = {'Education': 'Frequency'}, inplace = True)
df_loan2.index.name = "Education"
df_loan2.head()
# Out:
#            Frequency
# Education
# 1                383
# 0                 97

# %%
demo = df_loan2.index
freq = df_loan2['Frequency']
colors = ['red', 'blue']
plt.pie(freq, labels = demo, colors = colors, startangle = 90, autopct = '%.1f%%')
plt.show()

# %%
#Model Classification
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
df_loan_y = df_loan['Loan_Status'].values
df_loan_y[0:5]
# Out:
# array(['N', 'Y', 'Y', 'Y', 'Y'], dtype=object)

# %%
df_loan_x = df_loan
df_loan_x.drop(["Loan_Status", "Loan_ID"], axis = 1, inplace = True)
# Out:
# /anaconda3/envs/pythonGPU/lib/python3.7/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
from sklearn.model_selection import train_test_split 
x_train, x_test, y_train, y_test = train_test_split(df_loan_x, df_loan_y, test_size=0.40, random_state=4)
print ('Train set:', x_train.shape, y_train.shape)
print ('Test set:', x_test.shape, y_test.shape)
# Out:
# Train set: (288, 11) (288,)
# Test set: (192, 11) (192,)

# %%
from sklearn.neighbors import KNeighborsClassifier
Ks = 10
mean_acc = np.zeros((Ks-1))
std_acc = np.zeros((Ks-1))
ConfustionMx = [];
for n in range(1,Ks):
    
    #Train model and Predict
    loan1 = KNeighborsClassifier(n_neighbors = n).fit(x_train, y_train)
    loan2 = loan1.predict(x_test)
    mean_acc[n-1] = metrics.accuracy_score(y_test, loan2)
    
    std_acc[n-1] = np.std(loan2==y_test)/np.sqrt(loan2.shape[0])

mean_acc
# Out:
# array([0.5625    , 0.52083333, 0.58333333, 0.52604167, 0.63020833,
#        0.61458333, 0.65625   , 0.63541667, 0.66666667])

# %%
plt.plot(range(1,Ks), mean_acc, 'g')
plt.fill_between(range(1,Ks), mean_acc-1 * std_acc, mean_acc + 1 * std_acc, alpha=0.10)
plt.legend(('Accuracy', '+/- 3xstd'))
plt.ylabel('Accuracy')
plt.xlabel('Number of Neighbors (k)')
plt.tight_layout()
plt.show()

# %%
print("The best accuracy was with", mean_acc.max(), "with k=", mean_acc.argmax()+1)
# Out:
# The best accuracy was with 0.6666666666666666 with k= 9

# %%
k = 9
#Train model and predict

loan3 = KNeighborsClassifier(n_neighbors = k).fit(x_train, y_train)
loan3
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=9, p=2,
#                      weights='uniform')

# %%
test_set = metrics.accuracy_score(y_test, loan3.predict(x_test))
print("Test set Accuracy: {:.2f}".format(test_set))
# Out:
# Test set Accuracy: 0.67

# %%
tn, fp, fn, tp = confusion_matrix(y_test, loan3.predict(x_test)).ravel()
tn, fp, fn, tp
# Out:
# (9, 54, 10, 119)

# %%
aconf = confusion_matrix(y_test, loan3.predict(x_test))
aconf
# Out:
# array([[  9,  54],
#        [ 10, 119]])

# %%
conf = pd.DataFrame(aconf, columns = ['predN', 'predY'], index = ['actualN', 'actualY'])
conf
# Out:
#          predN  predY
# actualN      9     54
# actualY     10    119

# %%
precision = tp/(tp +fp)
precision
# Out:
# 0.6878612716763006

# %%
recall = tp/(tp + fn)
recall
# Out:
# 0.9224806201550387

# %%
knn_f1 = f1_score(y_test, loan3.predict(x_test), average = 'weighted')
knn_f1
# Out:
# 0.6015183330641253

# %%
accuracy = (tp + tn)/(tp + tn + fp + fn)
accuracy
# Out:
# 0.6666666666666666

# %%
#Decision Tree
from sklearn.tree import DecisionTreeClassifier 

loan4 = DecisionTreeClassifier (criterion = "entropy", max_depth = 4)
loan4
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=4,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
loan4 = loan4.fit(x_train, y_train)
loan4
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=4,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
loan5 = loan4.predict(x_test)
loan5
# Out:
# array(['Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'N',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'N',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y'], dtype=object)

# %%
test_set = metrics.accuracy_score(y_test, loan5)
print("Test set Accuracy: {:.2f}".format(test_set))
# Out:
# Test set Accuracy: 0.78

# %%
tn1, fp1, fn1, tp1 = confusion_matrix(y_test, loan5).ravel()
tn1, fp1, fn1, tp1
# Out:
# (25, 38, 5, 124)

# %%
bconf = confusion_matrix(y_test, loan5)
bconf
# Out:
# array([[ 25,  38],
#        [  5, 124]])

# %%
conf2 = pd.DataFrame(bconf, columns = ['predN', 'predY'], index = ['actualN', 'actualY'])
conf2
# Out:
#          predN  predY
# actualN     25     38
# actualY      5    124

# %%
precision1 = tp1/(tp1 + fp1)
precision1
# Out:
# 0.7654320987654321

# %%
recall1 = tp1/(tp1 + fn1)
recall1
# Out:
# 0.9612403100775194

# %%
accuracy1 = (tp1 + tn1)/(tp1 + tn1 + fp1 + fn1)
#Validating Accuracy
accuracy1
# Out:
# 0.7760416666666666

# %%
decision_f1 = f1_score(y_test, loan5, average = 'weighted')
decision_f1
# Out:
# 0.7490057920407938

# %%
df_loan_x.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 1       0        1          1          1              0             4583
# 2       0        1          0          1              1             3000
# 3       0        1          0          0              0             2583
# 4       0        0          0          1              0             6000
# 5       0        1          2          1              1             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#    Property_Area
# 1              0
# 2              1
# 3              1
# 4              1
# 5              1

# %%
from sklearn import tree
import pydotplus
from IPython.display import Image

x_train = pd.DataFrame(x_train)
y_train = pd.DataFrame(y_train)

#generating a graphic for the tree
dot_data = tree.export_graphviz(loan4, out_file = None,
                               feature_names = x_train.columns,
                               class_names = ["N", "Y"],
                               filled = True, rounded = True,
                               special_characters = True)
graph = pydotplus.graph_from_dot_data(dot_data)

# %%
graph

# %%
#Image(graph.create_png())

# %%
#KNN  vs. DECISION TREE

df = pd.DataFrame(np.array([[precision, recall, accuracy, knn_f1], [precision1, recall1, accuracy1, decision_f1]]), 
                 columns = ["Precision", "Recall", "Accuracy", "F1-Score"], index = ["KNN", "Decision Tree"])
df
# Out:
#                Precision    Recall  Accuracy  F1-Score
# KNN             0.687861  0.922481  0.666667  0.601518
# Decision Tree   0.765432  0.961240  0.776042  0.749006
